# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import pandas as pd
import colorTools as tools
plt.style.use('./EMplotter.mplstyle')

# %%
palette = tools.ColorPalette(n_colors=15, cmap=cm.viridis_r)
# Out:
# i =  1    Hex = #fde725    RGB = (253, 231,  37)
# i =  2    Hex = #d0e11c    RGB = (208, 225,  28)
# i =  3    Hex = #a0da39    RGB = (160, 218,  57)
# i =  4    Hex = #73d056    RGB = (115, 208,  86)
# i =  5    Hex = #4ac16d    RGB = ( 74, 193, 109)
# i =  6    Hex = #2db27d    RGB = ( 45, 178, 125)
# i =  7    Hex = #1fa187    RGB = ( 31, 161, 135)
# i =  8    Hex = #21908d    RGB = ( 33, 144, 141)
# i =  9    Hex = #277f8e    RGB = ( 39, 127, 142)
# i = 10    Hex = #2e6e8e    RGB = ( 46, 110, 142)
# i = 11    Hex = #365c8d    RGB = ( 54,  92, 141)
# i = 12    Hex = #3f4788    RGB = ( 63,  71, 136)
# i = 13    Hex = #46327e    RGB = ( 70,  50, 126)
# i = 14    Hex = #481b6d    RGB = ( 72,  27, 109)
# i = 15    Hex = #440154    RGB = ( 68,   1,  84)

# %%
c1='#045a8d'
c2='#bdc9e1'
n=5

palette = tools.ColorPalette(n_colors=n, c1=c1, c2=c2)
# Out:
# i =  1    Hex = #045a8d    RGB = (  4,  90, 141)
# i =  2    Hex = #3276a2    RGB = ( 50, 118, 162)
# i =  3    Hex = #6092b7    RGB = ( 96, 146, 183)
# i =  4    Hex = #8fadcc    RGB = (143, 173, 204)
# i =  5    Hex = #bdc9e1    RGB = (189, 201, 225)

# %%
c1='#fdd49e'
c2='#b30000'
#c2='#980043'
n=9

palette = tools.ColorPalette(n_colors=n, c1=c1, c2=c2)
# Out:
# i =  1    Hex = #fdd49e    RGB = (253, 212, 158)
# i =  2    Hex = #f4ba8a    RGB = (244, 186, 138)
# i =  3    Hex = #eb9f76    RGB = (235, 159, 118)
# i =  4    Hex = #e18463    RGB = (225, 132,  99)
# i =  5    Hex = #d86a4f    RGB = (216, 106,  79)
# i =  6    Hex = #cf503b    RGB = (207,  80,  59)
# i =  7    Hex = #c53528    RGB = (197,  53,  40)
# i =  8    Hex = #bc1a14    RGB = (188,  26,  20)
# i =  9    Hex = #b30000    RGB = (179,   0,   0)

# %%
c1='#fdd49e'
c2='#980043'
n=9

palette = tools.ColorPalette(n_colors=n, c1=c1, c2=c2)
# Out:
# i =  1    Hex = #fdd49e    RGB = (253, 212, 158)
# i =  2    Hex = #f0ba93    RGB = (240, 186, 147)
# i =  3    Hex = #e49f87    RGB = (228, 159, 135)
# i =  4    Hex = #d7847c    RGB = (215, 132, 124)
# i =  5    Hex = #cb6a70    RGB = (203, 106, 112)
# i =  6    Hex = #be5065    RGB = (190,  80, 101)
# i =  7    Hex = #b1355a    RGB = (177,  53,  90)
# i =  8    Hex = #a51a4e    RGB = (165,  26,  78)
# i =  9    Hex = #980043    RGB = (152,   0,  67)
